# %%
# Import the different module
import urllib2, json
from bs4 import BeautifulSoup

# %%
# Main variable to scrap the website
WEBSITE_URL = "http://www.dailystormer.com/section/featured-stories/page/{0}/"
NUMBER_OF_PAGES = 200

# Build a list of seed URL to scrap
def build_seed_pages(url, number_of_pages_wanted):
    seeds = []
    for page_number in range(1, number_of_pages_wanted + 1):
        seeds.append(url.format(page_number))
    return seeds

# Given the seeds get the pages urls

def build_crawl_listing(seeds):
    url_listing = []
    for seed in seeds:
        print seed
        opener = urllib2.build_opener()
        opener.addheaders = [('User-Agent', 'Mozilla/5.0')]
        response = opener.open(seed)
        soup = BeautifulSoup(response, 'html.parser')
        articles_list = soup.findAll("article", { "class" : "item-list" })
        for article in articles_list:
            title = article.find("h2")
            if title != -1:
                link = title.find('a')
                url_listing.append(link.get('href'))
    return url_listing

def get_text_from_a_url(url):
    opener = urllib2.build_opener()
    opener.addheaders = [('User-Agent', 'Mozilla/5.0')]
    response = opener.open(url)
    soup = BeautifulSoup(response, 'html.parser')
    article = soup.find("div", { "class" : "entry" })
    blockquotes = article.findAll('blockquote') # Remove citation
    for blockquote in blockquotes: 
        blockquote.decompose()
    links = article.findAll('a') # Remove link
    for link in links:
        link.decompose()
    paragraphs = article.findAll("p")
    words_articles = ""
    for paragraph in paragraphs[1:]:
        words_articles = words_articles + ' ' + paragraph.text
    return words_articles

def safe_data(json_to_dump, file_title):
    output = json.dumps( json_to_dump, ensure_ascii=False, encoding='utf8')
    with open("data/{0}.json".format(file_title), "w+") as save:
        save.write(output.encode('utf8'))

# %%
seeds = build_seed_pages(WEBSITE_URL, NUMBER_OF_PAGES)
crawl_listing = build_crawl_listing(seeds)
# Out:
# http://www.dailystormer.com/section/featured-stories/page/1/
# http://www.dailystormer.com/section/featured-stories/page/2/
# http://www.dailystormer.com/section/featured-stories/page/3/
# http://www.dailystormer.com/section/featured-stories/page/4/
# http://www.dailystormer.com/section/featured-stories/page/5/
# http://www.dailystormer.com/section/featured-stories/page/6/
# http://www.dailystormer.com/section/featured-stories/page/7/
# http://www.dailystormer.com/section/featured-stories/page/8/
# http://www.dailystormer.com/section/featured-stories/page/9/
# http://www.dailystormer.com/section/featured-stories/page/10/
# http://www.dailystormer.com/section/featured-stories/page/11/
# http://www.dailystormer.com/section/featured-stories/page/12/
# http://www.dailystormer.com/section/featured-stories/page/13/
# http://www.dailystormer.com/section/featured-stories/page/14/
# http://www.dailystormer.com/section/featured-stories/page/15/
# http://www.dailystormer.com/section/featured-stories/page/16/
# http://www.dailystormer.com/section/featured-stories/page/17/
# http://www.dailystormer.com/section/featured-stories/page/18/
# http://www.dailystormer.com/section/featured-stories/page/19/
# http://www.dailystormer.com/section/featured-stories/page/20/
# http://www.dailystormer.com/section/featured-stories/page/21/
# http://www.dailystormer.com/section/featured-stories/page/22/
# http://www.dailystormer.com/section/featured-stories/page/23/
# http://www.dailystormer.com/section/featured-stories/page/24/
# http://www.dailystormer.com/section/featured-stories/page/25/
# http://www.dailystormer.com/section/featured-stories/page/26/
# http://www.dailystormer.com/section/featured-stories/page/27/
# http://www.dailystormer.com/section/featured-stories/page/147/
# http://www.dailystormer.com/section/featured-stories/page/148/
# http://www.dailystormer.com/section/featured-stories/page/149/
# http://www.dailystormer.com/section/featured-stories/page/150/
# http://www.dailystormer.com/section/featured-stories/page/151/
# http://www.dailystormer.com/section/featured-stories/page/152/
# http://www.dailystormer.com/section/featured-stories/page/153/
# http://www.dailystormer.com/section/featured-stories/page/154/
# http://www.dailystormer.com/section/featured-stories/page/155/
# http://www.dailystormer.com/section/featured-stories/page/156/
# http://www.dailystormer.com/section/featured-stories/page/157/
# http://www.dailystormer.com/section/featured-stories/page/158/
# http://www.dailystormer.com/section/featured-stories/page/159/
# http://www.dailystormer.com/section/featured-stories/page/160/
# http://www.dailystormer.com/section/featured-stories/page/161/
# http://www.dailystormer.com/section/featured-stories/page/162/
# http://www.dailystormer.com/section/featured-stories/page/163/
# http://www.dailystormer.com/section/featured-stories/page/164/
# http://www.dailystormer.com/section/featured-stories/page/165/
# http://www.dailystormer.com/section/featured-stories/page/166/
# http://www.dailystormer.com/section/featured-stories/page/167/
# http://www.dailystormer.com/section/featured-stories/page/168/
# http://www.dailystormer.com/section/featured-stories/page/169/
# http://www.dailystormer.com/section/featured-stories/page/170/
# http://www.dailystormer.com/section/featured-stories/page/171/
# http://www.dailystormer.com/section/featured-stories/page/172/
# http://www.dailystormer.com/section/featured-stories/page/173/
# http://www.dailystormer.com/section/featured-stories/page/174/
# http://www.dailystormer.com/section/featured-stories/page/175/
# http://www.dailystormer.com/section/featured-stories/page/176/
# http://www.dailystormer.com/section/featured-stories/page/177/
# http://www.dailystormer.com/section/featured-stories/page/178/
# http://www.dailystormer.com/section/featured-stories/page/179/
# http://www.dailystormer.com/section/featured-stories/page/180/
# http://www.dailystormer.com/section/featured-stories/page/181/
# http://www.dailystormer.com/section/featured-stories/page/182/
# http://www.dailystormer.com/section/featured-stories/page/183/
# http://www.dailystormer.com/section/featured-stories/page/184/
# http://www.dailystormer.com/section/featured-stories/page/185/
# http://www.dailystormer.com/section/featured-stories/page/186/
# http://www.dailystormer.com/section/featured-stories/page/187/
# http://www.dailystormer.com/section/featured-stories/page/188/
# http://www.dailystormer.com/section/featured-stories/page/189/
# http://www.dailystormer.com/section/featured-stories/page/190/
# http://www.dailystormer.com/section/featured-stories/page/191/
# http://www.dailystormer.com/section/featured-stories/page/192/
# http://www.dailystormer.com/section/featured-stories/page/193/
# http://www.dailystormer.com/section/featured-stories/page/194/
# http://www.dailystormer.com/section/featured-stories/page/195/
# http://www.dailystormer.com/section/featured-stories/page/196/
# http://www.dailystormer.com/section/featured-stories/page/197/
# http://www.dailystormer.com/section/featured-stories/page/198/
# http://www.dailystormer.com/section/featured-stories/page/199/
# http://www.dailystormer.com/section/featured-stories/page/200/

# %%
list_of_article = []
for url in crawl_listing:
    list_of_article.append(get_text_from_a_url(url))

# %%
result_from_crawl = {}
for index, url in enumerate(crawl_listing):
    result_from_crawl[url] = list_of_article[index].encode('ascii', 'ignore')

# %%
safe_data(result_from_crawl, 'articles')
